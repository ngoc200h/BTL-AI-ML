# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.4-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.4

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %%
from google_play_scraper import app, Sort, reviews_all
from app_store_scraper import AppStore
import pandas as pd
import numpy as np
import json, os, uuid

# %%
g_reviews = reviews_all(
        "com.instagram.barcelona",
        sleep_milliseconds=0, # defaults to 0
        lang='en', # defaults to 'en'
        country='us', # defaults to 'us'
        sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
    )

# %%
#a_reviews = AppStore('us', 'threads-an-instagram-app', '6446901002')
#a_reviews.review()
a_reviews = AppStore(country='us', app_name='threads-an-instagram-app', app_id = '6446901002')
a_reviews.review(how_many=4900)
# Out:
# 2024-01-05 22:57:42,203 [INFO] Base - Initialised: AppStore('us', 'threads-an-instagram-app', 6446901002)
# 2024-01-05 22:57:42,204 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/us/app/threads-an-instagram-app/id6446901002
# 2024-01-05 22:57:47,831 [INFO] Base - [id:6446901002] Fetched 180 reviews (180 fetched in total)
# 2024-01-05 22:57:54,804 [INFO] Base - [id:6446901002] Fetched 220 reviews (220 fetched in total)
# 2024-01-05 22:58:01,939 [INFO] Base - [id:6446901002] Fetched 380 reviews (380 fetched in total)
# 2024-01-05 22:58:07,468 [INFO] Base - [id:6446901002] Fetched 620 reviews (620 fetched in total)
# 2024-01-05 22:58:13,156 [INFO] Base - [id:6446901002] Fetched 800 reviews (800 fetched in total)
# 2024-01-05 22:58:18,813 [INFO] Base - [id:6446901002] Fetched 1060 reviews (1060 fetched in total)
# 2024-01-05 22:58:25,293 [INFO] Base - [id:6446901002] Fetched 1200 reviews (1200 fetched in total)
# 2024-01-05 22:58:34,471 [INFO] Base - [id:6446901002] Fetched 1300 reviews (1300 fetched in total)
# 2024-01-05 22:58:40,419 [INFO] Base - [id:6446901002] Fetched 1400 reviews (1400 fetched in total)
# 2024-01-05 22:58:47,847 [INFO] Base - [id:6446901002] Fetched 1620 reviews (1620 fetched in total)
# 2024-01-05 22:58:54,295 [INFO] Base - [id:6446901002] Fetched 1840 reviews (1840 fetched in total)
# 2024-01-05 22:59:00,900 [INFO] Base - [id:6446901002] Fetched 1980 reviews (1980 fetched in total)
# 2024-01-05 22:59:06,782 [INFO] Base - [id:6446901002] Fetched 2120 reviews (2120 fetched in total)
# 2024-01-05 22:59:08,858 [INFO] Base - [id:6446901002] Fetched 2180 reviews (2180 fetched in total)

# %%
a_reviews.review()
# Out:
# 2024-01-05 23:01:01,707 [INFO] Base - [id:6446901002] Fetched 20 reviews (2200 fetched in total)

# %%
g_df = pd.DataFrame(np.array(g_reviews),columns=['review'])
g_df2 = g_df.join(pd.DataFrame(g_df.pop('review').tolist()))

# %%
g_df2.drop(columns={'userImage', 'reviewCreatedVersion'},inplace = True)
g_df2.rename(columns= {'score': 'rating','userName': 'user_name', 'reviewId': 'review_id', 'content': 'review_description', 'at': 'review_date', 'replyContent': 'developer_response', 'repliedAt': 'developer_response_date', 'thumbsUpCount': 'thumbs_up'},inplace = True)
g_df2.insert(loc=0, column='source', value='Google Play')
g_df2.insert(loc=3, column='review_title', value=None)
g_df2['laguage_code'] = 'en'
g_df2['country_code'] = 'us'

# %%
a_df = pd.DataFrame(np.array(a_reviews.reviews),columns=['review'])
a_df2 = a_df.join(pd.DataFrame(a_df.pop('review').tolist()))

# %%
a_df2.drop(columns={'isEdited'},inplace = True)
a_df2.insert(loc=0, column='source', value='App Store')
a_df2['developer_response_date'] = None
a_df2['thumbs_up'] = None
a_df2['laguage_code'] = 'en'
a_df2['country_code'] = 'us'
a_df2.insert(loc=1, column='review_id', value=[uuid.uuid4() for _ in range(len(a_df2.index))])
a_df2.rename(columns= {'review': 'review_description','userName': 'user_name', 'date': 'review_date','title': 'review_title', 'developerResponse': 'developer_response'},inplace = True)
a_df2 = a_df2.where(pd.notnull(a_df2), None)

# %%
result = pd.concat([g_df2,a_df2])
result
# Out:
#            source                             review_id           user_name  \
# 0     Google Play  38d09fae-c62d-4fa7-a52e-b355faf41d02              Edward
# 1     Google Play  2ce31e86-c2af-4c83-8c9a-357aa1ddd3c6     Jonathan Mckean
# 2     Google Play  b0dccf3e-521e-4313-bdf5-19ccba08c0e9           Apon Saha
# 3     Google Play  2147bbd5-8cdc-4df6-9aab-a29bca57c3c2  entertainment anup
# 4     Google Play  a4d93ffd-c146-4894-b8a2-4b5f4a56f442      Patti Petrella
# ...           ...                                   ...                 ...
# 2195    App Store  9e4d6764-7bd3-412e-aa77-a39146bae12a         Thought1234
# 2196    App Store  c3130d12-7048-4c43-8c7c-7459567b5246       apple ig user
# 2197    App Store  a48d071a-7ff7-41e0-aca8-3d65b8f1ca2f                Kēbē
# 2198    App Store  1638c8ee-ad31-4b3c-9615-2f053c01e354            redsox09
# 2199    App Store  d4902c0b-b523-47ce-9ac4-7ba21e7eb5b8     Guido Goldsteen
#
#                                            review_title  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 2195  Annoying it adds stuff that u don’t want to se...
# 2196                                        Malfunction
# 2197                   Threads are for weaving messages
# 2198                             Anything but Twitter 🤮
# 2199                                    Threads is good
#
#                                      review_description  rating thumbs_up  \
# 0     Threads by Meta is a fantastic app for staying...       5         0
# 1                  Nothing but scammers do not trust it       1         5
# 2                                               awesome       5         3
# 3                                              Nice app       3         6
# 4                   a great alternative to Twitter or x       5         0
# ...                                                 ...     ...       ...
# 2195  It has so many false information and I can’t i...       1      None
# 2196  This app malfunctions constantly. It won’t let...       1      None
# 2197  Threads Be for messaging and threads be for we...       5      None
# 2198                      White House needs an account.       5      None
# 2199  I see threads as a great way to increase stead...       5      None
#
#              review_date developer_response developer_response_date  \
# 0    2024-01-03 10:16:17               None                    None
# 1    2024-01-01 13:36:11               None                    None
# 2    2023-12-17 22:40:19               None                    None
# 3    2023-12-14 01:49:26               None                    None
# 4    2023-12-08 19:32:42               None                    None
# ...                  ...                ...                     ...
# 2195 2023-12-13 19:25:04                NaN                    None
# 2196 2023-12-13 03:01:16                NaN                    None
# 2197 2023-11-29 13:49:52                NaN                    None
# 2198 2023-11-27 18:51:49                NaN                    None
# 2199 2023-11-19 12:21:03                NaN                    None
#
#           appVersion laguage_code country_code
# 0     312.0.0.33.108           en           us
# 1               None           en           us
# 2               None           en           us
# 3     310.0.0.36.327           en           us
# 4     310.0.0.36.327           en           us
# ...              ...          ...          ...
# 2195             NaN           en           us
# 2196             NaN           en           us
# 2197             NaN           en           us
# 2198             NaN           en           us
# 2199             NaN           en           us
#
# [47818 rows x 13 columns]
